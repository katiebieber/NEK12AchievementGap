# %%
library(dplyr)
library(ggplot2)
library(lubridate)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Attaching package: ‘lubridate’
#
# The following object is masked from ‘package:base’:
#
#     date

# %% [markdown]
# Read csv file into data frame.

# %%
Profraw <- read.csv("NeSAProficiency.csv")

# %% [markdown]
# Filter out Native Hawaiian and Two or More Races fields as there are less than 10 in the state so that field is masked (throws an error if you don't filter).

# %%
Proficiency <- Profraw %>% filter(RACE_ETHNICITY!="Native Hawaiian or Other Pacific Islander", RACE_ETHNICITY!="Two Or More Races")

# %% [markdown]
# Create another column for Proficiency Percentage and turn the column into raw numbers not alpha characters like Percent_Proficient column is.

# %%
Proficiency$ProfPerc <- as.numeric(as.character(Proficiency$PERCENT_PROFICIENT))

# %% [markdown]
# Read data head.

# %%
head(Proficiency)
# Out:
#   DATAYEARS SUBJECT_DESCRIPTION RACE_ETHNICITY                   GENDER FRL
# 1  910      READING             American Indian or Alaska Native MALE   FRL
# 2 1011      READING             American Indian or Alaska Native MALE   FRL
# 3 1112      READING             American Indian or Alaska Native MALE   FRL
# 4 1213      READING             American Indian or Alaska Native MALE   FRL
# 5 1314      READING             American Indian or Alaska Native MALE   FRL
# 6 1415      READING             American Indian or Alaska Native MALE   FRL
#   PERCENT_PROFICIENT ProfPerc
# 1 35.97              35.97
# 2 38.17              38.17
# 3 38.64              38.64
# 4 41.45              41.45
# 5 44.82              44.82
# 6 46.46              46.46

# %% [markdown]
# Filter gender males and suject reading only.

# %%
profracemales <- Proficiency %>%
  filter(GENDER == "MALE", SUBJECT_DESCRIPTION == "MATHEMATICS" )

# %% [markdown]
# Plot line graph of males by race, free and reduced lunch vs not free and reduced lunch, with the x as the data year and the y as the proficiency percentage. Do a facet wrap to include a separate line graph for each race. Set width and height of each graph to 10x10.

# %%
library(repr)
options(repr.plot.width=10, repr.plot.height=10)
ggplot(data=profracemales, aes(x=DATAYEARS, y=ProfPerc, group=FRL, color=FRL)) + geom_line() + labs(x="School Year", y="Proficiency Rate", title="Mathematics Proficiency by Race, Males", subtitle="Poverty vs. Non-poverty", caption="Graphic by Katie Bieber") + facet_wrap(~RACE_ETHNICITY, scales='free_x') + theme(axis.line=element_line()) + scale_x_continuous(labels=as.character(profracemales$DATAYEARS),breaks=profracemales$DATAYEARS)
# Out:
# plot without title

# %% [markdown]
# Export file as pdf set with same 10x10 width and height.

# %%
ggsave("profracemalesmath.pdf", width=10, height=10)
